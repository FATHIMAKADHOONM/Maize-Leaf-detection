# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            font-size:300%;
#            font-family: Times New Roman, Times, serif;
#     letter-spacing:0.5px"><b> Maize Leaf Disease Detection using Deep Learning</b></div><br>

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            font-size:300%;
#            font-family: Times New Roman, Times, serif;
#     letter-spacing:0.5px"></div>
#
# <p style="padding: 10px;color:black;font-size:140%;font-family: Times New Roman, Times, serif;"> Maize disease protection is important for global food security[1] , while the recognition of maize leaf diseases at early stage is the key part of crop protection.Through reading the relevant literature,three kinds of maize leaf diseases were selected as the research
# objects in this paper .The 4205 images of maize leaves were anlayzed and assigned as four class labels
# manually, such as healthy leaf, big spot leaf, gray spot leaf and rust leaf.

# %%
import numpy as np 
import pandas as pd 


import os
for dirname, _, filenames in os.walk(r'C:\Users\mahab\Downloads\Dataset(MaizeProject)'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\blightTest.jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (10).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (100).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1000).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1001).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1002).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1003).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1004).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1005).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1006).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1007).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1008).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1009).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (101).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1010).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1011).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1012).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1013).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1014).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1015).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1016).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1017).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1018).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1019).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (102).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1020).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1021).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1022).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1023).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1024).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1025).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1026).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1027).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1028).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1029).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (103).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1030).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1031).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1032).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1033).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1034).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1035).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1036).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1037).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1038).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1039).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (104).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1040).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1041).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1042).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1043).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1044).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1045).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1046).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1047).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1048).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1049).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (105).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1050).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1051).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1052).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1053).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1054).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1055).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1056).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1057).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1058).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1059).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (106).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1060).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1061).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1062).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1063).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1064).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1065).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1066).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1067).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1068).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1069).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (107).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1070).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1071).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1072).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1073).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1074).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1075).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1076).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1077).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1078).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1079).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (108).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1080).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1081).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1082).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1083).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1084).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1085).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1086).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1087).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1088).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1089).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (109).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1090).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1091).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1092).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1093).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1094).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1095).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1096).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1097).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1098).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1099).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (11).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (110).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1100).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1101).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1102).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1103).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1104).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1105).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1106).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1107).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1108).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1109).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (111).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1110).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1111).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1112).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1113).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1114).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1115).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1116).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1117).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1118).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1119).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (112).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1120).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1121).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1122).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1123).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1124).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1125).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1126).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1127).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1128).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1129).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (113).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1130).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1131).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1132).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1133).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1134).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1135).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1136).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1137).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1138).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1139).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (114).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1140).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1141).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1142).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1143).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1144).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (1145).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (115).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (116).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (117).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (118).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (119).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (12).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (120).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (121).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (122).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (123).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (124).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (125).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (126).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (127).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (128).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (129).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (13).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (130).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (131).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (132).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (133).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (134).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (135).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (136).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (137).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (138).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (139).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (14).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (140).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (141).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (142).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (143).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (144).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (145).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (146).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (147).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (148).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (149).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (15).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (150).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (151).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (152).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (153).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (154).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (155).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (156).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (157).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (158).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (159).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (16).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (160).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (161).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (162).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (163).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (164).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (165).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (166).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (167).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (168).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (169).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (17).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (170).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (171).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (172).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (173).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (174).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (175).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (176).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (177).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (178).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (179).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (18).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (180).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (181).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (182).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (183).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (184).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (185).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (186).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (187).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (188).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (189).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (19).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (190).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (191).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (192).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (193).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (194).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (195).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (196).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (197).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (198).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (199).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (2).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (20).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (200).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (201).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (202).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (203).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (204).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (205).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (206).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (207).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (208).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (209).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (21).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (210).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (211).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (212).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (213).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (214).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (215).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (216).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (217).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (218).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (219).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (22).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (220).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (221).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (222).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (223).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (224).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (225).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (226).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (227).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (228).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (229).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (23).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (230).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (231).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (232).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (233).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (234).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (235).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (236).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (237).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (238).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (239).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (24).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (240).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (241).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (242).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (243).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (244).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (245).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (246).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (247).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (248).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (249).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (25).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (250).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (251).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (252).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (253).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (254).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (255).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (256).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (257).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (258).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (259).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (26).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (260).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (261).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (262).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (263).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (264).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (265).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (266).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (267).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (268).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (269).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (27).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (270).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (271).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (272).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (273).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (274).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (275).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (276).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (277).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (278).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (279).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (28).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (280).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (281).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (282).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (283).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (284).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (285).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (286).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (287).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (288).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (289).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (29).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (290).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (291).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (292).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (293).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (294).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (295).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (296).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (297).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (298).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (299).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (3).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (30).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (300).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (301).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (302).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (303).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (304).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (305).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (306).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (307).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (308).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (309).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (31).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (310).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (311).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (312).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (313).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (314).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (315).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (316).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (317).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (318).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (319).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (32).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (320).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (321).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (322).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (323).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (324).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (325).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (326).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (327).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (328).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (329).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (33).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (330).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (331).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (332).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (333).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (334).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (335).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (336).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (337).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (338).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (339).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (34).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (340).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (341).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (342).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (343).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (344).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (345).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (346).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (347).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (348).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (349).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (35).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (350).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (351).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (352).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (353).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (354).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (355).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (356).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (357).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (358).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (359).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (36).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (360).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (361).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (362).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (363).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (364).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (365).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (366).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (367).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (368).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (369).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (37).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (370).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (371).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (372).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (373).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (374).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (375).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (376).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (377).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (378).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (379).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (38).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (380).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (381).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (382).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (383).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (384).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (385).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (386).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (387).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (388).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (389).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (39).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (390).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (391).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (392).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (393).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (394).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (395).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (396).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (397).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (398).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (399).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (4).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (40).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (400).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (401).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (402).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (403).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (404).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (405).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (406).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (407).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (408).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (409).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (41).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (410).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (411).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (412).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (413).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (414).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (415).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (416).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (417).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (418).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (419).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (42).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (420).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (421).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (422).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (423).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (424).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (425).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (426).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (427).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (428).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (429).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (43).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (430).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (431).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (432).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (433).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (434).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (435).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (436).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (437).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (438).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (439).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (44).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (440).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (441).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (442).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (443).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (444).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (445).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (446).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (447).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (448).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (449).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (45).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (450).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (451).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (452).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (453).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (454).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (455).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (456).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (457).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (458).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (459).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (46).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (460).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (461).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (462).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (463).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (464).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (465).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (466).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (467).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (468).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (469).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (47).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (470).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (471).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (472).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (473).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (474).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (475).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (476).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (477).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (478).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (479).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (48).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (480).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (481).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (482).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (483).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (484).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (485).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (486).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (487).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (488).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (489).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (49).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (490).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (491).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (492).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (493).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (494).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (495).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (496).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (497).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (498).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (499).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (5).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (50).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (500).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (501).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (502).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (503).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (504).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (505).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (506).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (507).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (508).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (509).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (51).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (510).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (511).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (512).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (513).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (514).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (515).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (516).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (517).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (518).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (519).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (52).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (520).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (521).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (522).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (523).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (524).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (525).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (526).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (527).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (528).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (529).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (53).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (530).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (531).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (532).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\Corn_Blight (533).JPG
# ...
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (812).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (813).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (814).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (815).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (816).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (817).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (818).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (819).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (82).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (820).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (821).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (822).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (823).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (824).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (825).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (826).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (827).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (828).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (829).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (83).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (830).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (831).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (832).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (833).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (834).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (835).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (836).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (837).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (838).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (839).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (84).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (840).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (841).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (842).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (843).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (844).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (845).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (846).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (847).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (848).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (849).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (85).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (850).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (851).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (852).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (853).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (854).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (855).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (856).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (857).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (858).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (859).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (86).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (860).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (861).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (862).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (863).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (864).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (865).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (866).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (867).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (868).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (869).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (87).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (870).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (871).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (872).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (873).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (874).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (875).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (876).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (877).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (878).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (879).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (88).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (880).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (881).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (882).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (883).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (884).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (885).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (886).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (887).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (888).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (889).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (89).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (890).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (891).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (892).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (893).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (894).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (895).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (896).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (897).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (898).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (899).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (9).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (90).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (900).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (901).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (902).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (903).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (904).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (905).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (906).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (907).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (908).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (909).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (91).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (910).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (911).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (912).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (913).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (914).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (915).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (916).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (917).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (918).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (919).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (92).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (920).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (921).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (922).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (923).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (924).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (925).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (926).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (927).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (928).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (929).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (93).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (930).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (931).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (932).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (933).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (934).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (935).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (936).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (937).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (938).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (939).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (94).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (940).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (941).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (942).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (943).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (944).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (945).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (946).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (947).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (948).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (949).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (95).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (950).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (951).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (952).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (953).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (954).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (955).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (956).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (957).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (958).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (959).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (96).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (960).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (961).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (962).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (963).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (964).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (965).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (966).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (967).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (968).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (969).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (97).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (970).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (971).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (972).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (973).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (974).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (975).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (976).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (977).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (978).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (979).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (98).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (980).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (981).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (982).JPG
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (983).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (984).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (985).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (986).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (987).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (988).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (989).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (99).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (990).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (991).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (992).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (993).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (994).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (995).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (996).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (997).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (998).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\Corn_Health (999).jpg
# C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\HealthyTest.jpg

# %%
import os
import numpy as np
import pandas as pd
import tqdm as tqdm
import cv2 as cv
import keras
from keras.models import Sequential
from keras.layers import Conv2D , MaxPooling2D ,GlobalAveragePooling2D ,Flatten , Dense , Dropout , BatchNormalization 
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf
tf.keras.applications.VGG16
from keras.applications.vgg16 import VGG16
from keras.layers import Dense, Dropout, Activation, Flatten, GlobalAveragePooling2D
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D
from keras.models import Model

# %%
encoder = OneHotEncoder()     
encoder.fit([[0],[1],[2],[3]])
# Out:
# OneHotEncoder()

# %%
input_path = []
label = []

# %%
data = []
paths = []
result = []
fpath = []
for r,d,f in os.walk(r"C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight"):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r,file))
for path in paths:
    img = Image.open(path)
    img = img.resize((224,224))
    img = np.array(img)
    if(img.shape == (224,224,3)):
        data.append(img)
        label.append(0)
        input_path.append(os.path.join("Blight","Blight",path))
        result.append(encoder.transform([[0]]).toarray())
print(len(paths))
# Out:
# 276

# %%
paths = []
for r,d,f in os.walk(r"C:\Users\mahab\Downloads\Dataset(MaizeProject)\Common_Rust"):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r,file))
for path in paths:
    img = Image.open(path)
    img = img.resize((224,224))
    img = np.array(img)
    if(img.shape == (224,224,3)):
        data.append(img)
        label.append(1)
        input_path.append(os.path.join("Common_Rust","Common_Rust",path))
        result.append(encoder.transform([[1]]).toarray())
print(len(paths))
# Out:
# 114

# %%
paths = []
for r,d,f in os.walk(r"C:\Users\mahab\Downloads\Dataset(MaizeProject)\Gray_Leaf_Spot"):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r,file))
for path in paths:
    img = Image.open(path)
    img = img.resize((224,224))
    img = np.array(img)
    if(img.shape == (224,224,3)):
        data.append(img)
        label.append(2)
        input_path.append(os.path.join("Gray_Leaf_Spot","Gray_Leaf_Spot",path))
        result.append(encoder.transform([[2]]).toarray())
print(len(paths))
print(len(input_path))
# Out:
# 128
# 513

# %%
paths = []
for r,d,f in os.walk(r"C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy"):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r,file))
for path in paths:
    img = Image.open(path)
    img = img.resize((224,224))
    img = np.array(img)
    if(img.shape == (224,224,3)):
        data.append(img)
        label.append(3)
        input_path.append(os.path.join("Healthy","Healthy",path))
        result.append(encoder.transform([[3]]).toarray())
print(len(paths))
# Out:
# 1142

# %%
df = pd.DataFrame()
df['images'] = input_path
df['label'] = label
df=df.sample(frac=1).reset_index(drop=True)
df.head()
# Out:
#                                               images  label
# 0  C:\Users\mahab\Downloads\Dataset(MaizeProject)...      3
# 1  C:\Users\mahab\Downloads\Dataset(MaizeProject)...      3
# 2  C:\Users\mahab\Downloads\Dataset(MaizeProject)...      3
# 3  C:\Users\mahab\Downloads\Dataset(MaizeProject)...      3
# 4  C:\Users\mahab\Downloads\Dataset(MaizeProject)...      3

# %%
pd.unique(df['label'])
# Out:
# array([3, 0, 1, 2], dtype=int64)

# %%
import seaborn as sns
sns.countplot(df['label'])
# Out:
# C:\Users\mahab\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
print("Total no.of images are :",len(result))
# Out:
# Total no.of images are : 1655

# %%
result = np.array(result)
result = result.reshape(-1,4)

# %%
data = np.array(data)
data.shape
# Out:
# (1655, 224, 224, 3)

# %%
# %matplotlib inline
plt.figure(figsize=(10, 10))
for i in range(6):
    plt.subplot(1, 6, i+1)
    plt.imshow(data[i], cmap="gray")
    plt.axis('off')
plt.show()

# %%
x_train , x_test , y_train , y_test = train_test_split(data , result , test_size = 0.25 , shuffle = True , random_state = 100)

# %%
print("Shape of an image in x_train : ",x_train[0].shape)
print("Shape of an image in x_test : ",x_test[0].shape)
# Out:
# Shape of an image in x_train :  (224, 224, 3)
# Shape of an image in x_test :  (224, 224, 3)

# %%
x_train = np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
print("x_train Shape : ", x_train.shape) 
print("x_test Shape : ", x_test.shape)
print("y_train Shape: ", y_train.shape) 
print("y_test Shape: ", y_test.shape)
# Out:
# x_train Shape :  (1241, 224, 224, 3)
# x_test Shape :  (414, 224, 224, 3)
# y_train Shape:  (1241, 4)
# y_test Shape:  (414, 4)

# %%
modelVGG = VGG16(include_top = False,weights = 'imagenet',classifier_activation = 'softmax',input_shape = (224, 224, 3))

# %%
for layer in modelVGG.layers:
    layer.trainable = False

# %%
num_classes = 4
for (i,layer) in enumerate(modelVGG.layers):
    print(str(i) + " "+ layer.__class__.__name__, layer.trainable)
    def lw(bottom_model,num_classes):
        top_model = bottom_model.output
        top_model = GlobalAveragePooling2D()(top_model)
        top_model = Dense(1024,activation='relu')(top_model)
        top_model = Dense(1024,activation='relu')(top_model)
        top_model = Dense(512,activation='relu')(top_model)
        top_model = Dense(4,activation='softmax')(top_model)
        return top_model
# Out:
# 0 InputLayer False
# 1 Conv2D False
# 2 Conv2D False
# 3 MaxPooling2D False
# 4 Conv2D False
# 5 Conv2D False
# 6 MaxPooling2D False
# 7 Conv2D False
# 8 Conv2D False
# 9 Conv2D False
# 10 MaxPooling2D False
# 11 Conv2D False
# 12 Conv2D False
# 13 Conv2D False
# 14 MaxPooling2D False
# 15 Conv2D False
# 16 Conv2D False
# 17 Conv2D False
# 18 MaxPooling2D False

# %%
num_classes = 4
FC_Head = lw(modelVGG , num_classes)
model = Model(inputs = modelVGG.input,outputs = FC_Head)

# %%
print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              525312
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  dense_2 (Dense)             (None, 512)               524800
#
#  dense_3 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 16,816,452
# Trainable params: 2,101,764
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None

# %%
# summarize filters in each convolutional layer
#from keras.applications.vgg16 import VGG16
#from matplotlib import pyplot
# load the model
#model = VGG16()
# summarize filter shapes
for layer in model.layers:
# check for convolutional layer
    if 'conv' not in layer.name:
        continue
    # get filter weights
    filters, biases = layer.get_weights()
    print(layer.name, filters.shape)
# Out:
# block1_conv1 (3, 3, 3, 64)
# block1_conv2 (3, 3, 64, 64)
# block2_conv1 (3, 3, 64, 128)
# block2_conv2 (3, 3, 128, 128)
# block3_conv1 (3, 3, 128, 256)
# block3_conv2 (3, 3, 256, 256)
# block3_conv3 (3, 3, 256, 256)
# block4_conv1 (3, 3, 256, 512)
# block4_conv2 (3, 3, 512, 512)
# block4_conv3 (3, 3, 512, 512)
# block5_conv1 (3, 3, 512, 512)
# block5_conv2 (3, 3, 512, 512)
# block5_conv3 (3, 3, 512, 512)

# %%
# normalize filter values to 0-1 so we can visualize them
f_min, f_max = filters.min(), filters.max()
filters = (filters - f_min) / (f_max - f_min)

# %%
import matplotlib.pyplot as plt
f = plt.figure(figsize=(16,16))
nof_filters, ix = 4, 1
for i in range(nof_filters):
    f = filters[:, :, :, i]
    # plot each channel separately
    for j in range(3):
        ax = plt.subplot(nof_filters, 3, ix)
        ax.set_xticks([])
        ax.set_yticks([])
        # plot filter channel in grayscale
        plt.imshow(f[:, :, j], cmap='gray')
        ix += 1
# show the figure
plt.show()

# %%
model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
from keras.preprocessing.image import ImageDataGenerator 
datagen = ImageDataGenerator(
    featurewise_center=False,  
    samplewise_center=False, 
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,  
    zca_whitening=False,
    rotation_range=50,
    width_shift_range=0.01, 
    height_shift_range=0.01, 
    horizontal_flip=False, 
    vertical_flip=False)

datagen.fit(x_train)

# %%
history = model.fit(x_train , y_train , epochs = 40 , validation_data = (x_test , y_test), verbose = 1)
# Out:
# Epoch 1/40
# 39/39 [==============================] - 368s 9s/step - loss: 1.1836 - accuracy: 0.7921 - val_loss: 0.2872 - val_accuracy: 0.8865
# Epoch 2/40
# 39/39 [==============================] - 388s 10s/step - loss: 0.2360 - accuracy: 0.9098 - val_loss: 0.2344 - val_accuracy: 0.9106
# Epoch 3/40
# 39/39 [==============================] - 387s 10s/step - loss: 0.1145 - accuracy: 0.9621 - val_loss: 0.2111 - val_accuracy: 0.9203
# Epoch 4/40
# 39/39 [==============================] - 387s 10s/step - loss: 0.0763 - accuracy: 0.9782 - val_loss: 0.2257 - val_accuracy: 0.9106
# Epoch 5/40
# 39/39 [==============================] - 4462s 117s/step - loss: 0.0517 - accuracy: 0.9815 - val_loss: 0.2438 - val_accuracy: 0.9251
# Epoch 6/40
# 39/39 [==============================] - 378s 10s/step - loss: 0.0341 - accuracy: 0.9911 - val_loss: 0.2627 - val_accuracy: 0.9155
# Epoch 7/40
# 39/39 [==============================] - 383s 10s/step - loss: 0.0328 - accuracy: 0.9911 - val_loss: 0.2831 - val_accuracy: 0.9227
# Epoch 8/40
# 39/39 [==============================] - 385s 10s/step - loss: 0.0175 - accuracy: 0.9960 - val_loss: 0.2619 - val_accuracy: 0.9130
# Epoch 9/40
# 39/39 [==============================] - 386s 10s/step - loss: 0.0280 - accuracy: 0.9903 - val_loss: 0.2822 - val_accuracy: 0.9058
# Epoch 10/40
# 39/39 [==============================] - 1781s 47s/step - loss: 0.0150 - accuracy: 0.9960 - val_loss: 0.3818 - val_accuracy: 0.9251
# Epoch 11/40
# 39/39 [==============================] - 384s 10s/step - loss: 0.0102 - accuracy: 0.9944 - val_loss: 0.5193 - val_accuracy: 0.9300
# Epoch 12/40
# 39/39 [==============================] - 385s 10s/step - loss: 0.1242 - accuracy: 0.9645 - val_loss: 0.3825 - val_accuracy: 0.8768
# Epoch 13/40
# 39/39 [==============================] - 387s 10s/step - loss: 0.0650 - accuracy: 0.9774 - val_loss: 0.8057 - val_accuracy: 0.8164
# Epoch 14/40
# 39/39 [==============================] - 389s 10s/step - loss: 0.1240 - accuracy: 0.9613 - val_loss: 0.4165 - val_accuracy: 0.9010
# Epoch 15/40
# 39/39 [==============================] - 388s 10s/step - loss: 0.0568 - accuracy: 0.9790 - val_loss: 0.3265 - val_accuracy: 0.9058
# Epoch 16/40
# 39/39 [==============================] - 397s 10s/step - loss: 0.0428 - accuracy: 0.9887 - val_loss: 0.4540 - val_accuracy: 0.9155
# Epoch 17/40
# 39/39 [==============================] - 496s 13s/step - loss: 0.0247 - accuracy: 0.9887 - val_loss: 0.3059 - val_accuracy: 0.9203
# Epoch 18/40
# 39/39 [==============================] - 377s 10s/step - loss: 0.0073 - accuracy: 0.9976 - val_loss: 0.3368 - val_accuracy: 0.9082
# Epoch 19/40
# 39/39 [==============================] - 378s 10s/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.3244 - val_accuracy: 0.9106
# Epoch 20/40
# 39/39 [==============================] - 378s 10s/step - loss: 0.0043 - accuracy: 0.9968 - val_loss: 0.3404 - val_accuracy: 0.9155
# Epoch 21/40
# 39/39 [==============================] - 378s 10s/step - loss: 0.0032 - accuracy: 0.9984 - val_loss: 0.3608 - val_accuracy: 0.9155
# Epoch 22/40
# 39/39 [==============================] - 377s 10s/step - loss: 0.0027 - accuracy: 0.9976 - val_loss: 0.3913 - val_accuracy: 0.9155
# Epoch 23/40
# 39/39 [==============================] - 378s 10s/step - loss: 0.0034 - accuracy: 0.9976 - val_loss: 0.4125 - val_accuracy: 0.9130
# Epoch 24/40
# 39/39 [==============================] - 378s 10s/step - loss: 0.0029 - accuracy: 0.9968 - val_loss: 0.4273 - val_accuracy: 0.9155
# Epoch 25/40
# 39/39 [==============================] - 384s 10s/step - loss: 0.0026 - accuracy: 0.9984 - val_loss: 0.4551 - val_accuracy: 0.9155
# Epoch 26/40
# 39/39 [==============================] - 383s 10s/step - loss: 0.0025 - accuracy: 0.9984 - val_loss: 0.4690 - val_accuracy: 0.9179
# Epoch 27/40
# 39/39 [==============================] - 383s 10s/step - loss: 0.0026 - accuracy: 0.9968 - val_loss: 0.4842 - val_accuracy: 0.9179
# Epoch 28/40
# 39/39 [==============================] - 382s 10s/step - loss: 0.0025 - accuracy: 0.9976 - val_loss: 0.4957 - val_accuracy: 0.9106
# Epoch 29/40
# 39/39 [==============================] - 383s 10s/step - loss: 0.0025 - accuracy: 0.9976 - val_loss: 0.5101 - val_accuracy: 0.9106
# Epoch 30/40
# 39/39 [==============================] - 383s 10s/step - loss: 0.0024 - accuracy: 0.9984 - val_loss: 0.5206 - val_accuracy: 0.9106
# Epoch 31/40
# 39/39 [==============================] - 382s 10s/step - loss: 0.0026 - accuracy: 0.9984 - val_loss: 0.5292 - val_accuracy: 0.9106
# Epoch 32/40
# 39/39 [==============================] - 383s 10s/step - loss: 0.0024 - accuracy: 0.9976 - val_loss: 0.5390 - val_accuracy: 0.9082
# Epoch 33/40
# 39/39 [==============================] - 384s 10s/step - loss: 0.0026 - accuracy: 0.9984 - val_loss: 0.5501 - val_accuracy: 0.9130
# Epoch 34/40
# 39/39 [==============================] - 386s 10s/step - loss: 0.0027 - accuracy: 0.9984 - val_loss: 0.5635 - val_accuracy: 0.9130
# Epoch 35/40
# 39/39 [==============================] - 389s 10s/step - loss: 0.0025 - accuracy: 0.9984 - val_loss: 0.5690 - val_accuracy: 0.9082
# Epoch 36/40
# 39/39 [==============================] - 388s 10s/step - loss: 0.0025 - accuracy: 0.9976 - val_loss: 0.5798 - val_accuracy: 0.9106
# Epoch 37/40
# 39/39 [==============================] - 36513s 961s/step - loss: 0.0025 - accuracy: 0.9976 - val_loss: 0.5772 - val_accuracy: 0.9106
# Epoch 38/40
# 39/39 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9976

# %%
# %matplotlib inline
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

# %%
plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()

plt.show()

# %%
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend(loc=0)
plt.figure()

plt.show()

# %%
Avg_loss=sum(loss)/len(loss)
print(format(Avg_loss,".2f"))
# Out:
# 0.06

# %%
def names(number):
    if number==0:
        return "It's a leaf with disease BLIGHT"
    elif number==1:
        return "It's a leaf with disease Common Rust"
    elif number==2:
        return "It's a leaf with disease Gray_Leaf_Spot"
    elif number==3:
        return "It's a Healthy leaf"

# %%
from matplotlib.pyplot import imshow
def Prediction(img):
    #img = Image.open(r"../input/corn-or-maize-leaf-disease-dataset/data/Blight/Corn_Blight (1010).JPG")
    x = np.array(img.resize((224,224)))
    x = x.reshape(1,224,224,3)
    res = model.predict_on_batch(x)
    classification = np.where(res == np.amax(res))[1][0]
    imshow(img)
    print(str(res[0][classification]*100) + '% Confidence ' + names(classification))

# %%
img = Image.open(r"C:\Users\mahab\Downloads\Dataset(MaizeProject)\Healthy\HealthyTest.JPG")
Prediction(img)
# Out:
# 100.0% Confidence It's a Healthy leaf

# %%
img = Image.open(r"C:\Users\mahab\Downloads\Dataset(MaizeProject)\Common_Rust\RustTest.JPG")
Prediction(img)
# Out:
# 100.0% Confidence It's a leaf with disease Common Rust

# %%
img = Image.open(r"C:\Users\mahab\Downloads\Dataset(MaizeProject)\Gray_Leaf_Spot\GrayTest.JPG")
Prediction(img)
# Out:
# 100.0% Confidence It's a leaf with disease Gray_Leaf_Spot

# %%
img = Image.open(r"C:\Users\mahab\Downloads\Dataset(MaizeProject)\Blight\blightTest.JPG")
Prediction(img)
# Out:
# 99.99996423721313% Confidence It's a leaf with disease BLIGHT

# %%
y_pred = model.predict(x_test)
# Out:
# 13/13 [==============================] - 102s 8s/step

# %%
from sklearn.metrics import classification_report, confusion_matrix
y_pred=np.argmax(y_pred, axis=1)
y_test=np.argmax(y_test, axis=1)
cnn_cm = confusion_matrix(y_test, y_pred)
print(cnn_cm)
from sklearn.metrics import accuracy_score
cm_acc = round(accuracy_score(y_pred,y_test) * 100, 2)
print(cm_acc,'%')
# Out:
# [[ 56   7   6   1]
#  [  4  28   0   0]
#  [ 12   7  13   0]
#  [  0   0   0 280]]
# 91.06 %

# %%
TP = cnn_cm[0][0]
FN = cnn_cm[0][1]
FP = cnn_cm[1][0]
TN = cnn_cm[1][1]

sensitivity=TP / (TP+FN)
print('sensitivity',sensitivity)
specificity= TN / (TN+FP)
print('specificity',specificity)
accuracy=(TP+TN) / (TN+TP+FN+FP)
print('Accuracy',accuracy)
# Out:
# sensitivity 0.8888888888888888
# specificity 0.875
# Accuracy 0.8842105263157894

# %%
import seaborn as sns
import matplotlib.pyplot as plt

f, ax=plt.subplots(figsize=(5,5))
sns.heatmap(cnn_cm,annot=True,linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.78      0.79        72
#            1       0.88      0.67      0.76        42
#            2       0.41      0.68      0.51        19
#            3       1.00      1.00      1.00       281
#
#     accuracy                           0.91       414
#    macro avg       0.77      0.78      0.76       414
# weighted avg       0.93      0.91      0.91       414

# %%
print('Max val_acc achieved: %.2f' %(max(history.history['val_accuracy'])*100), '%')
print('Max acc achieved: %.2f' %(max(history.history['accuracy'])*100), '%')
# Out:
# Max val_acc achieved: 93.00 %
# Max acc achieved: 99.84 %

# %%
print('Final val_acc achieved: %.2f' %(history.history['val_accuracy'][-1]*100), '%')
print('Final acc achieved: %.2f' %(history.history['accuracy'][-1]*100), '%')
# Out:
# Final val_acc achieved: 91.06 %
# Final acc achieved: 99.84 %
